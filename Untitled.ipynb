# %%
import cv2
from matplotlib import pyplot as plt
import numpy as np
# %matplotlib inline

# %%
img = cv2.imread("sudoku-original.jpg")

# %%
print img
# Out:
# [[[175 171 160]
#   [173 167 156]
#   [178 172 161]
#   ...,
#   [213 207 202]
#   [213 207 202]
#   [213 207 202]]
#
#  [[175 171 160]
#   [173 167 156]
#   [178 172 161]
#   ...,
#   [212 206 201]
#   [212 206 201]
#   [212 206 201]]
#
#  [[172 168 157]
#   [172 166 155]
#   [173 167 156]
#   ...,
#   [213 207 202]
#   [213 207 202]
#   [213 207 202]]
#
#  ...,
#  [[ 43  43  43]
#   [ 43  43  43]
#   [ 39  41  41]
#   ...,
#   [132 130 130]
#   [135 133 133]
#   [138 136 136]]
#
#  [[ 46  46  46]
#   [ 45  45  45]
#   [ 41  43  43]
#   ...,
#   [134 132 132]
#   [136 134 134]
#   [136 134 134]]
#
#  [[ 48  48  48]
#   [ 47  47  47]
#   [ 42  44  44]
#   ...,
#   [134 132 132]
#   [134 132 132]
#   [133 131 131]]]

# %%
plt.imshow(img)

# %%
blur = cv2.GaussianBlur(img, (11,11), 0)

# %%
plt.imshow(blur)

# %%
blank_image = np.zeros(img.shape, np.uint8)

# %%
img.dtype
# Out:
# dtype('uint8')

# %%
th2 = cv2.adaptiveThreshold(img,255,cv2.ADAPTIVE_THRESH_MEAN_C,cv2.THRESH_BINARY,11,2)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-9-7681acda501c> in <module>()
# ----> 1 th2 = cv2.adaptiveThreshold(img,255,cv2.ADAPTIVE_THRESH_MEAN_C,cv2.THRESH_BINARY,11,2)
#
# error: /home/rajat/Downloads/opencv-3.2.0/modules/imgproc/src/thresh.cpp:1446: error: (-215) src.type() == CV_8UC1 in function adaptiveThreshold
